# %% [markdown]
# <a href="https://colab.research.google.com/github/mailesaketh/AI_Projects/blob/main/AI_2_Treasurehunt_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello, i am the treasure hunt robot")
# Out:
# hello, i am the treasure hunt robot

# %%
map_rooms={"A":["B","C"],
      "B":["D"],
      "C":["D"],
     "D":["G"],
      "G":[]
     }
def treasure_hunt(start,goal):
    to_do=[start]
    visited=[]
    order=[]
    while to_do:
        room=to_do.pop(0)
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room==goal:
            return order
        for nxt in map_rooms[room]:
            to_do.append(nxt)
    return order
order=treasure_hunt("A","G")
print("BFS ORDER:",order)
print("length of path:",len(order))
# Out:
# BFS ORDER: ['A', 'B', 'C', 'D', 'G']
# length of path: 5

# %%
def treasure_hunt(start,goal):
    to_do=[start]
    visited=[]
    order=[]
    while to_do:
        room=to_do.pop()
        if room in visited:
            continue
        visited.append(room)
        order.append(room)
        if room==goal:
            return order
        for nxt in map_rooms[room]:
            to_do.append(nxt)
    return order
order=treasure_hunt("A","G")
print("DS ORDER:",order)
print("length of path:",len(order))
# Out:
# DS ORDER: ['A', 'C', 'D', 'G']
# length of path: 4

# %%
door_cost={("A","B"):1,
           ("B","D"):1,
           ("D","G"):1,
           ("A","C"):5,
           ("C","D"):1
          }
def path_cost(path):
    total=0
    for i in range(len(path) - 1):
        door =(path[i],path[i+1])
        total+= door_cost[door]
    return total
path1=["A","B","D","G"]
path2=["A","C","D","G"]
path1_cost=path_cost(path1)
path2_cost=path_cost(path2)
print("cost of path1: " ,path1_cost)
print("cost of path2: " ,path2_cost)

if path1_cost <= path2_cost :
    print("best path: ", path1 , "best cost: ",path1_cost)
else:
     print("best path: ", path2 , "best cost: ",path2_cost)
# Out:
# cost of path1:  3
# cost of path2:  7
# best path:  ['A', 'B', 'D', 'G'] best cost:  3
